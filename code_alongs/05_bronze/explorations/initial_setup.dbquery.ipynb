-- %%
SHOW CATALOGS;

CREATE CATALOG IF NOT EXISTS supply_chain_demo;


CREATE SCHEMA IF NOT EXISTS supply_chain_demo.raw_data;
CREATE SCHEMA IF NOT EXISTS supply_chain_demo.bronze;
CREATE SCHEMA IF NOT EXISTS supply_chain_demo.silver;
CREATE SCHEMA IF NOT EXISTS supply_chain_demo.gold;

CREATE VOLUME IF NOT EXISTS supply_chain_demo.default.raw;

-- vi fick en föär mycket och behöver radera
DROP SCHEMA IF EXISTS supply_chain_demo.raw_data;
