# %%
# %sql
SHOW CATALOGS;

# %%
# %sql

SHOW SCHEMAS IN data;

# %%
# %sql
SHOW VOLUMES IN data.olympic_games;

LIST '/Volumes/data/olympic_games/raw_data';

# %%
# %sql
LIST '/Volumes/data/olympic_games/raw_data';

# %%
# %python
# Skapa en path med python och Spark 

volume_path = '/Volumes/data/olympic_games/raw_data'

files_in_volume = spark.sql(f"LIST'{volume_path}';")

# Vi får en dataframe 
files_in_volume # lazy evaluation - vi ser endast schemat, inte actual data

# %%
# Display - för att få ut datan 

files_in_volume.display()

# eller 

display(files_in_volume)

# %%
# När man jobbar i sql sparas det i _sqldf så länge man inte sparar över det
_sqldf.display()
