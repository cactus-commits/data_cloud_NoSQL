# %% [markdown]
# Create new pipeline
#
# Pipelines can be found under 'Jobs & Pipelines'
#
# När man kör pipeline körs alla python och sql scripts under transformations.
#
# ### Initial setup
# - Kan göras med en SQL query i foldern explorations.
# - Skapa tre olika folders under 'raw'
#     - data
#     - logs
#     - metadata
#
# Detta göra för att det ska funkan när man ingestar ny data längre fram.
# Se 05_bronze - initial setup
